# %% [markdown]
# # Bank Customer Segmentation Analysis
# ## Data Cleaning and RFM Modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('Kitabxanalar uğurla yükləndi!')
